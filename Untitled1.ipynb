# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnamittal01/data-science/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# READING THE DATA FROM DIFFERENT SOURCES

# %%
import pandas as pd
from io import StringIO
data='{"employee_name":"James","email":"james@gmail.com","job_profile":[{"tirle1":"Team Lead","title2":"Sr.Developer"}]}'
df=pd.read_json(StringIO(data))

# %%
df
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                          job_profile
# 0  {'tirle1': 'Team Lead', 'title2': 'Sr.Developer'}

# %%
###convert this data frame back into json
df.to_json()
# Out:
# '{"employee_name":{"0":"James"},"email":{"0":"james@gmail.com"},"job_profile":{"0":{"tirle1":"Team Lead","title2":"Sr.Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_name":"James","email":"james@gmail.com","job_profile":{"tirle1":"Team Lead","title2":"Sr.Developer"}}}'

# %%
df.to_json(orient='records') ##same as we have entered
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job_profile":{"tirle1":"Team Lead","title2":"Sr.Developer"}}]'

# %%
## reading from a html file

# %%
df=pd.read_html("https://www.fdic.gov/bank-failures/failed-bank-list")

# %%
print(type(df[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df))
# Out:
# <class 'list'>

# %%
data=pd.read_html("https://en.wikipedia.org/wiki/Mobile_country_code",match="Country")

# %%
data[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
data_html=pd.read_html("https://en.wikipedia.org/wiki/Mobile_country_code",match="Country",header=0)

# %%
data_html[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...
